# %%
 # imoorting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import svm
from sklearn.datasets import make_blobs
## we create 40 seperable points
X,y=make_blobs(n_samples=40,centers=2,random_state=20)
#fit the model ,don't  regularize for illlustration purpose
model=svm.SVC(kernel='linear',C=1)
model.fit(X,y)
#display the data in a graph formp
plt.scatter(X[:,0],X[:,1],c=y,s=30,cmap=plt.cm.Paired)
plt.show()

# %%
#using the model to predict unknown data
new_data = [[3,4],[5,6]]
print(model.predict(new_data))
# Out:
# [0 1]

# %%
model=svm.SVC(kernel='linear',C=1000)
model.fit(X,y)
#display the data in a graph formp
plt.scatter(X[:,0],X[:,1],c=y,s=30,cmap=plt.cm.Paired)
#plot the decision function
ax=plt.gca()
xlim=ax.get_xlim()
ylim=ax.get_ylim()
#create grid to evaluate model
xx=np.linspace(xlim[0],xlim[1],30)
yy=np.linspace(ylim[0],ylim[1],30)
YY,XX=np.meshgrid(yy,xx)
xy=np.vstack([XX.ravel(),YY.ravel()]).T
Z=model.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX,YY,Z,colors='k',levels=[-1,0,1],
           alpha=.5,linstyles=['---','-','--'])
#plot support vectors
ax.scatter(model.support_vectors_[:,0],
           model.support_vectors_[:,1],s=100,
           linewidth=1,facecolors='none')
plt.show()
# Out:
# C:\Users\klikh\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: The following kwargs were not used by contour: 'linstyles'
